# %%
import psycopg2

connection = psycopg2.connect(database="db_learner", user="user_wsl", password="WSLpostgres##++24", host="127.0.0.1", port=54321)
connection.autocommit = True
cursor = connection.cursor()

# %%
def select_all_query(table_name: str):
    query = f"""SELECT * FROM {table_name};"""
    return query


def display_results(table_column_names: list, results: list):
    table_columns_length = [len(x) for x in table_column_names]
    for result in results:
        for value in range(len(result)):
            row_data = result[value]
            if row_data:
                row_data = str(row_data)
                if len(row_data) > table_columns_length[value]:
                    table_columns_length[value] = len(row_data)
    dashes_plus = ""
    for num in range(len(table_columns_length)):
        dashes_plus = dashes_plus + "+" + '-'*(table_columns_length[num]+2)
    dashes_plus = dashes_plus + "+"
    
    print(dashes_plus)
    
    table_headers = ""
    for num in range(len(table_column_names)):
        table_headers = table_headers + f"| {table_column_names[num]:^{table_columns_length[num]}} "
    table_headers = table_headers + "|"
    print(table_headers)
    
    print(dashes_plus)
    
    for result in results:
        table_row = ""
        for value in range(len(result)):
            row_data = result[value]
            if row_data is None:
                row_data = "NULL"            
            table_row = table_row + "|" + f"{str(row_data):^{table_columns_length[value]+2}}"
        print(table_row + "|")
    print(dashes_plus)
    print(f"{len(results)} rows returned")

def execute_display_query_results(query: str = "", table_column_names: list = [], results: list = []): 
    if query:
        print(f"Executing the query: {query}")
    if len(query) > 2 and (table_column_names or results):
        print("You can only pass in the query alone or the table_column_names and results list")
        assert False
    if query and not table_column_names and not results:
        cursor.execute(query)
        results = cursor.fetchall()    
        table_column_names = [desc[0] for desc in cursor.description]
    
    display_results(table_column_names, results)

# %%
execute_display_query_results(select_all_query("tbl_person"))
# Out:
# Executing the query: SELECT * FROM tbl_person;
# +------------+-----------+-------+--------+
# | first_name | last_name | email | gender |
# +------------+-----------+-------+--------+
# +------------+-----------+-------+--------+
# 0 rows returned

# %%
cursor.execute("""create table tbl_person (
	first_name VARCHAR(50),
	last_name VARCHAR(50),
	email VARCHAR(50),
	gender VARCHAR(50)
);""")

# %%
insert_query = """
insert into tbl_person (first_name, last_name, email, gender) values ('Murvyn', 'Byres', 'mbyres0@cocolog-nifty.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Skell', 'Krimmer', 'skrimmer1@artisteer.com', 'Genderfluid');
insert into tbl_person (first_name, last_name, email, gender) values ('Baily', 'Cargill', 'bcargill2@nps.gov', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Dane', 'Dami', 'ddami3@macromedia.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Ade', 'Likely', 'alikely4@china.com.cn', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Seymour', 'Berrane', 'sberrane5@abc.net.au', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Rosabel', 'Gandey', 'rgandey6@tuttocitta.it', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Aigneis', 'Deavin', 'adeavin7@cam.ac.uk', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Hetty', 'Idel', 'hidel8@histats.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Natty', 'MacNeachtain', 'nmacneachtain9@tiny.cc', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Burton', 'Banthorpe', 'bbanthorpea@geocities.jp', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Katey', 'Chapple', 'kchappleb@earthlink.net', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Shannen', 'Little', 'slittlec@list-manage.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Ingaberg', 'Cromley', 'icromleyd@wikia.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Wilfrid', 'Bonnette', 'wbonnettee@timesonline.co.uk', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Ludovika', 'Quincee', 'lquinceef@github.io', 'Genderfluid');
insert into tbl_person (first_name, last_name, email, gender) values ('Parry', 'McRannell', 'pmcrannellg@google.nl', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Vaclav', 'Kunrad', 'vkunradh@uiuc.edu', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Halette', 'Tollett', 'htolletti@go.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Cullan', 'Rookesby', 'crookesbyj@google.co.uk', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Barry', 'Gatenby', 'bgatenbyk@businesswire.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Hi', 'Chezelle', 'hchezellel@apache.org', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Bertrand', 'Ovington', 'bovingtonm@java.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Fayre', 'Sciacovelli', 'fsciacovellin@fotki.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Lorelle', 'Ingerson', 'lingersono@360.cn', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Flory', 'Clemendot', 'fclemendotp@webeden.co.uk', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Alison', 'Ghidoli', 'aghidoliq@addtoany.com', 'Bigender');
insert into tbl_person (first_name, last_name, email, gender) values ('Rochester', 'Deacock', 'rdeacockr@omniture.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Felic', 'Prosch', 'fproschs@t.co', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Obed', 'Downe', 'odownet@weibo.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Ross', 'Grime', 'rgrimeu@wordpress.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Sharla', 'Sherwyn', 'ssherwynv@google.cn', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Noah', 'Bellson', 'nbellsonw@dagondesign.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Oliviero', 'Yegorov', 'oyegorovx@ucla.edu', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Sheppard', 'Crosher', 'scroshery@ustream.tv', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Ailsun', 'Kinforth', 'akinforthz@smugmug.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Nathan', 'Teager', 'nteager10@exblog.jp', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Beauregard', 'Philliskirk', 'bphilliskirk11@census.gov', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Marget', 'Ferdinand', 'mferdinand12@amazon.co.jp', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Tedra', 'Giovanetti', 'tgiovanetti13@ameblo.jp', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Peria', 'Macauley', 'pmacauley14@twitter.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Melisent', 'Le Provost', 'mleprovost15@so-net.ne.jp', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Curtice', 'Sandall', 'csandall16@privacy.gov.au', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Catlee', 'Roundtree', 'croundtree17@flavors.me', 'Genderfluid');
insert into tbl_person (first_name, last_name, email, gender) values ('Gonzales', 'Urwen', 'gurwen18@yellowbook.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Aloin', 'Alwood', 'aalwood19@ameblo.jp', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Olympie', 'Tabbernor', 'otabbernor1a@parallels.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Ariadne', 'Cleland', 'acleland1b@geocities.jp', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Roze', 'Garber', 'rgarber1c@lycos.com', 'Genderqueer');
insert into tbl_person (first_name, last_name, email, gender) values ('Michale', 'Robbe', 'mrobbe1d@bloglines.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Tobe', 'McRae', 'tmcrae1e@elpais.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Kariotta', 'Erwin', 'kerwin1f@cbslocal.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Abbe', 'Painswick', 'apainswick1g@amazon.de', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Creighton', 'Haldon', 'chaldon1h@amazon.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Hussein', 'Hauch', 'hhauch1i@jugem.jp', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Kelby', 'Grute', 'kgrute1j@soup.io', 'Non-binary');
insert into tbl_person (first_name, last_name, email, gender) values ('Thoma', 'Lumbers', 'tlumbers1k@eventbrite.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Morten', 'Newbold', 'mnewbold1l@discuz.net', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('June', 'Konke', 'jkonke1m@google.nl', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Martie', 'Dewis', 'mdewis1n@cnet.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Marsha', 'Bidgod', 'mbidgod1o@cargocollective.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Neda', 'McArthur', 'nmcarthur1p@technorati.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Deanne', 'Giorgietto', 'dgiorgietto1q@blogspot.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Hartley', 'Raffin', 'hraffin1r@reuters.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Onfre', 'Brownsworth', 'obrownsworth1s@bravesites.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Joseph', 'Gilffilland', 'jgilffilland1t@skyrock.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Pedro', 'Kief', 'pkief1u@fotki.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Ignacius', 'Newling', 'inewling1v@barnesandnoble.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Donia', 'Jaggers', 'djaggers1w@wikipedia.org', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Norry', 'McCritichie', 'nmccritichie1x@123-reg.co.uk', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Ring', 'Lintin', 'rlintin1y@artisteer.com', 'Bigender');
insert into tbl_person (first_name, last_name, email, gender) values ('Arron', 'Fortesquieu', 'afortesquieu1z@weather.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Faulkner', 'Borris', 'fborris20@amazonaws.com', 'Polygender');
insert into tbl_person (first_name, last_name, email, gender) values ('Vinnie', 'Salasar', 'vsalasar21@marketwatch.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Everett', 'Franzini', 'efranzini22@cisco.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Konstance', 'Worpole', 'kworpole23@fc2.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Rochelle', 'Ronci', 'rronci24@360.cn', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Robby', 'Slemmonds', 'rslemmonds25@disqus.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Inga', 'Iremonger', 'iiremonger26@4shared.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Jenifer', 'Loftus', 'jloftus27@usnews.com', 'Genderfluid');
insert into tbl_person (first_name, last_name, email, gender) values ('Paulie', 'Albasiny', 'palbasiny28@goo.ne.jp', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Hillard', 'Ligerton', 'hligerton29@abc.net.au', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Chiarra', 'Chinnock', 'cchinnock2a@yellowbook.com', 'Non-binary');
insert into tbl_person (first_name, last_name, email, gender) values ('Malvina', 'Ladel', 'mladel2b@people.com.cn', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Padgett', 'Heiner', 'pheiner2c@shutterfly.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Lexie', 'Beccero', 'lbeccero2d@yale.edu', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Katinka', 'Carslaw', 'kcarslaw2e@umich.edu', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Sheridan', 'Siddall', 'ssiddall2f@delicious.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Kerwinn', 'Petronis', 'kpetronis2g@jiathis.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Gabie', 'Kellough', 'gkellough2h@nymag.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Deidre', 'Bengochea', 'dbengochea2i@nature.com', 'Agender');
insert into tbl_person (first_name, last_name, email, gender) values ('Etta', 'Redferne', 'eredferne2j@shop-pro.jp', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Timoteo', 'Linden', 'tlinden2k@paginegialle.it', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Brantley', 'Creech', 'bcreech2l@opera.com', 'Male');
insert into tbl_person (first_name, last_name, email, gender) values ('Cleveland', 'Mutch', 'cmutch2m@umich.edu', 'Agender');
insert into tbl_person (first_name, last_name, email, gender) values ('Ellette', 'Farrow', 'efarrow2n@phoca.cz', 'Genderqueer');
insert into tbl_person (first_name, last_name, email, gender) values ('Charlean', 'Le feaver', 'clefeaver2o@surveymonkey.com', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Lavina', 'Kimbrey', 'lkimbrey2p@tuttocitta.it', 'Female');
insert into tbl_person (first_name, last_name, email, gender) values ('Annamaria', 'Dugdale', 'adugdale2q@w3.org', 'Genderqueer');
insert into tbl_person (first_name, last_name, email, gender) values ('Raddie', 'Storer', 'rstorer2r@alibaba.com', 'Male');
"""
cursor.execute(insert_query)

# %%
execute_display_query_results(select_all_query("tbl_person"))
# Out:
# Executing the query: SELECT * FROM tbl_person;
# +------------+--------------+-------------------------------+-------------+
# | first_name |  last_name   |             email             |   gender    |
# +------------+--------------+-------------------------------+-------------+
# |   Murvyn   |    Byres     |   mbyres0@cocolog-nifty.com   |    Male     |
# |   Skell    |   Krimmer    |    skrimmer1@artisteer.com    | Genderfluid |
# |   Baily    |   Cargill    |       bcargill2@nps.gov       |    Male     |
# |    Dane    |     Dami     |     ddami3@macromedia.com     |    Male     |
# |    Ade     |    Likely    |     alikely4@china.com.cn     |    Male     |
# |  Seymour   |   Berrane    |     sberrane5@abc.net.au      |    Male     |
# |  Rosabel   |    Gandey    |    rgandey6@tuttocitta.it     |   Female    |
# |  Aigneis   |    Deavin    |      adeavin7@cam.ac.uk       |   Female    |
# |   Hetty    |     Idel     |      hidel8@histats.com       |   Female    |
# ...
